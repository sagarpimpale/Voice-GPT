# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python39\site-packages\transformers\utils\import_utils.py:1126, in _LazyModule._get_module(self, module_name)
#    1125 try:
# -> 1126     return importlib.import_module("." + module_name, self.__name__)
#    1127 except Exception as e:
#
# File C:\ProgramData\Anaconda3\lib\importlib\__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# ...

# %%
import speech_recognition as sr
import torch
import transformers
from transformers import pipeline


pipeline = transformers.pipeline("text-generation")

# Initialize the speech recognition engine
r = sr.Recognizer()

# Initialize the ChatGPT pipeline
chatgpt = pipeline('text-generation', model='microsoft/DialoGPT-medium')

while True:
    # Listen for user input
    with sr.Microphone() as source:
        print("Say something!")
        audio = r.listen(source)

    # Convert the audio to text
    try:
        text = r.recognize_google(audio)
        print(f"You said: {text}")
    except sr.UnknownValueError:
        print("Google Speech Recognition could not understand audio")
        continue

    # Generate a response using ChatGPT
    response = chatgpt(text)[0]['generated_text']
    print(f"Response: {response}")

    # TODO: Convert the response to speech using a text-to-speech engine
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python39\site-packages\transformers\utils\import_utils.py:1126, in _LazyModule._get_module(self, module_name)
#    1125 try:
# -> 1126     return importlib.import_module("." + module_name, self.__name__)
#    1127 except Exception as e:
#
# File C:\ProgramData\Anaconda3\lib\importlib\__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# ...

# %%
import pyttsx3
import openai
import os

# Set up text-to-speech engine
engine = pyttsx3.init()

# Set up OpenAI API credentials
openai.api_key = os.environ["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"]

# Set up GPT-3 model
model_engine = "text-davinci-002"
prompt = "Hi, how can I assist you today?"
model_response = openai.Completion.create(
    engine=model_engine,
    prompt=prompt,
    max_tokens=1024,
    n=1,
    stop=None,
    temperature=0.5,
)

# Get GPT-3 response
response = model_response.choices[0].text.strip()

# Speak response using text-to-speech engine
engine.say(response)
engine.runAndWait()
# Out:
#   Input In [1]
#     openai.api_key = os.environ"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"
#                                ^
# SyntaxError: invalid syntax

# %%
import pyttsx3
import requests
import os

# Set up text-to-speech engine
engine = pyttsx3.init()

API_URL = "https://api-inference.huggingface.co/models/gpt2"
headers = {"Authorization": f"Bearer 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"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()


# Set up GPT-3 model
model_engine = "text-davinci-002"
prompt = "Hi, how can I assist you today?"
model_response = openai.Completion.create(
    engine=model_engine,
    prompt=prompt,
    max_tokens=1024,
    n=1,
    stop=None,
    temperature=0.5,
)

# Get GPT-3 response
response = model_response.choices[0].text.strip()

# Speak response using text-to-speech engine
engine.say(response)
engine.runAndWait()
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Input In [5], in <cell line: 19>()
#      17 model_engine = "text-davinci-002"
#      18 prompt = "Hi, how can I assist you today?"
# ---> 19 model_response = openai.Completion.create(
#      20     engine=model_engine,
#      21     prompt=prompt,
#      22     max_tokens=1024,
#      23     n=1,
#      24     stop=None,
#      25     temperature=0.5,
#      26 )
#      28 # Get GPT-3 response
#      29 response = model_response.choices[0].text.strip()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\openai\api_resources\completion.py:25, in Completion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# ...
